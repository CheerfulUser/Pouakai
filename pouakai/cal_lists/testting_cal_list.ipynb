# %%
import pandas as pd

# %%
df = pd.read_csv('/home/phys/astronomy/zgl12/pouakai/pouakai/cal_lists/moa_master_dark_list.csv')

# %%
df
# Out:
#                  name telescope  exptime            jd                date  \
# 0      D24680-200-m-1    MOA-II      200  2.460542e+06          2024-08-19
# 1      D24680-200-m-2    MOA-II      200  2.460542e+06          2024-08-19
# 2      D24680-200-m-3    MOA-II      200  2.460542e+06          2024-08-19
# 3      D24680-200-m-4    MOA-II      200  2.460542e+06          2024-08-19
# 4      D24680-200-m-5    MOA-II      200  2.460542e+06          2024-08-19
# ...               ...       ...      ...           ...                 ...
# 32894    D21178-0-m-6    MOA-II        0  2.459123e+06          2020-09-30
# 32895    D21178-0-m-7    MOA-II        0  2.459123e+06          2020-09-30
# 32896    D21178-0-m-8    MOA-II        0  2.459123e+06          2020-09-30
# 32897    D21178-0-m-9    MOA-II        0  2.459123e+06          2020-09-30
# 32898   D21178-0-m-10    MOA-II        0  2.459123e+06          2020-09-30
#
# ...

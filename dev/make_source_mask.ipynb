# %%
import sys
sys.path.append('../pouakai')
from core import *
# %matplotlib widget
from astropy.stats import sigma_clip
import numpy as np
import matplotlib.pyplot as plot

# %%
hdu = fits.open('A7238-yse257Aa-R-3_cal.fits.gz')

image = hdu[0].data
mask = hdu[1].data
header = hdu[0].header
wcs = WCS(header)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Invalid DATE-OBS format '        2022-03-08''. [astropy.wcs.wcs]

# %%
fig, ax = plt.subplots()
cal = ap_photom(data=image,wcs=wcs, header=header,mask =mask,
                    threshold=5,cal_model='ckmodel',ax=ax,brightlim=15)
# Out:
# 1484
# 1478
# [84.78027822 84.78044561 84.78179229 ... 85.51435127 85.51424464
#  85.51428684]
# close sources
# no matches  0
# 442
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a = cal.ap_photom.iloc[100]

# %%
a.xcenter
# Out:
# 1586.2505108775238

# %%
line = image[:,int(a.xcenter)]
med = np.nanmedian(line)
std = np.nanstd(line)

plt.figure()
plt.plot(image[:,int(a.xcenter)])
plt.axhline(med+100,c='r')
plt.axvline(a.ycenter)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
image.shape
# Out:
# (4096, 2048)

# %%
np.nanmedian(image)
# Out:
# 2139.6979523765403

# %%
med
# Out:
# 2141.8503824560944

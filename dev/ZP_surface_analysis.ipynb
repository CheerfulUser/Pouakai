# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
# %matplotlib notebook

from scipy.ndimage import gaussian_filter

# %%
files = glob('zp_surface/*R-10_*.npy')
print(len(files))
# Out:
# 22

# %%
arrs = []
for f in files:
    arrs += [np.load(f)]
arrs = np.array(arrs)

# %%
a = 10**(-2/5*arrs)

# %%
med = np.nanmedian(a / np.nanmedian(a,axis=(1,2))[:,np.newaxis,np.newaxis],axis=0)
std = np.nanstd(a / np.nanmedian(a,axis=(1,2))[:,np.newaxis,np.newaxis],axis=0)

# %%
plt.figure()
plt.imshow(med)
plt.colorbar()
plt.tight_layout()
plt.figure()
plt.imshow(std/med)
plt.colorbar()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Test dart images

# %%
files = glob('/Users/rri38/Documents/work/data/mjo/moa/zp_surface/dart/*R-3_*.npy')

print(len(files))
# Out:
# 539

# %%
arrs = []
for f in files[:100]:
    arrs += [np.load(f)]
arrs = np.array(arrs)

a = 10**(-2/5*arrs)

m = np.median(a,axis=(1,2))[:,np.newaxis,np.newaxis]
med = np.median(a / m,axis=0)

for i in range(5):
    i += 1
    for f in files[i*100:i*100]:
        arrs += [np.load(f)]
        arrs = np.array(arrs)

        a = 10**(-2/5*arrs)
        m = np.median(a,axis=(1,2))[:,np.newaxis,np.newaxis]
        med = np.median(np.array([med, a / m,]),axis=0)

# %%
test = gaussian_filter(med,100)

# %%
plt.figure()
plt.imshow(med)
plt.colorbar()
plt.tight_layout()

plt.figure()
plt.imshow(test)
plt.colorbar()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
m = np.mean(a,axis=(1,2))[:,np.newaxis,np.newaxis]
med = np.mean(a / m,axis=0)
std = np.std(a / m,axis=0)


plt.figure()
plt.imshow(std/med)
plt.colorbar()
plt.tight_layout()

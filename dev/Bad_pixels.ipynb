# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
# %matplotlib notebook
from astropy.io import fits

# %% [markdown]
# ## Chip 1

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-1_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
np.save('chip1_bpix',mask)

# %% [markdown]
# ## Chip 1

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-1_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
np.save('chip1_bpix',mask)

# %% [markdown]
# ## Chip 2

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-2_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
mask[:,370:380] = 1
np.save('chip2_bpix',mask)

# %% [markdown]
# ## Chip 3

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-3_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)

np.save('chip3_bpix',mask)

# %% [markdown]
# ## Chip 4

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-4_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
mask[1085:,80:86] = 1
mask[1120:,1056:1060] = 1
np.save('chip4_bpix',mask)

# %% [markdown]
# ## Chip 5

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-5_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
mask[3597:,1884:1886] = 1
mask[3544:,1962:1968] = 1
np.save('chip5_bpix',mask)

# %% [markdown]
# ## Chip 6

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-6_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Chip 7

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-7_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
mask[1524:,1236:1242] = 1
mask[:128,1238:1242] = 1

np.save('chip7_bpix',mask)

# %% [markdown]
# ## Chip 8

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-8_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
mask[1883:,192:197] = 1
mask[:500,461:466] = 1

mask[960:,245:251] = 1
mask[2334:,461:467] = 1
mask[2390:,702:707] = 1

mask[610:,1153:1158] = 1
mask[197:,1646:1651] = 1
mask[2265:,1675:1678] = 1
mask[3756:,1905:1908] = 1

np.save('chip8_bpix',mask)

# %% [markdown]
# ## Chip 9

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-9_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)
mask[4003:,1667:1667] = 1

np.save('chip9_bpix',mask)

# %% [markdown]
# ## Chip 10

# %%
data = fits.open('../../../data/mjo/moa/lsst_test/A6469-lsst1-R-10_cal.fits.gz')[0].data

plt.figure()
plt.imshow(data,vmin=np.percentile(data,16),vmax=np.percentile(data,85),origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.zeros_like(data).astype(int)


np.save('chip10_bpix',mask)
